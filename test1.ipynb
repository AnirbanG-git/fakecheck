# %%
import sys, torch
print(sys.executable)
print(torch.__version__, torch.version.cuda, torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# /root/fakecheck/.venv/bin/python
# 2.9.0+cu126 12.6 True NVIDIA H100 80GB HBM3
